# %% [markdown]
# # Skip-gram word2vec
#
# In this notebook, I'll lead you through using TensorFlow to implement the word2vec algorithm using the skip-gram architecture. By implementing this, you'll learn about embedding words for use in natural language processing. This will come in handy when dealing with things like machine translation.
#
# ## Readings
#
# Here are the resources I used to build this notebook. I suggest reading these either beforehand or while you're working on this material.
#
# * A really good [conceptual overview](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/) of word2vec from Chris McCormick
# * [First word2vec paper](https://arxiv.org/pdf/1301.3781.pdf) from Mikolov et al.
# * [NIPS paper](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf) with improvements for word2vec also from Mikolov et al.
# * An [implementation of word2vec](http://www.thushv.com/natural_language_processing/word2vec-part-1-nlp-with-deep-learning-with-tensorflow-skip-gram/) from Thushan Ganegedara
# * TensorFlow [word2vec tutorial](https://www.tensorflow.org/tutorials/word2vec)
#
# ## Word embeddings
#
# When you're dealing with words in text, you end up with tens of thousands of classes to predict, one for each word. Trying to one-hot encode these words is massively inefficient, you'll have one element set to 1 and the other 50,000 set to 0. The matrix multiplication going into the first hidden layer will have almost all of the resulting values be zero. This a huge waste of computation.
#
# ![one-hot encodings](assets/one_hot_encoding.png)
#
# To solve this problem and greatly increase the efficiency of our networks, we use what are called embeddings. Embeddings are just a fully connected layer like you've seen before. We call this layer the embedding layer and the weights are embedding weights. We skip the multiplication into the embedding layer by instead directly grabbing the hidden layer values from the weight matrix. We can do this because the multiplication of a one-hot encoded vector with a matrix returns the row of the matrix corresponding the index of the "on" input unit.
#
# ![lookup](assets/lookup_matrix.png)
#
# Instead of doing the matrix multiplication, we use the weight matrix as a lookup table. We encode the words as integers, for example "heart" is encoded as 958, "mind" as 18094. Then to get hidden layer values for "heart", you just take the 958th row of the embedding matrix. This process is called an **embedding lookup** and the number of hidden units is the **embedding dimension**.
#
# <img src='assets/tokenize_lookup.png' width=500>
#
# There is nothing magical going on here. The embedding lookup table is just a weight matrix. The embedding layer is just a hidden layer. The lookup is just a shortcut for the matrix multiplication. The lookup table is trained just like any weight matrix as well.
#
# Embeddings aren't only used for words of course. You can use them for any model where you have a massive number of classes. A particular type of model called **Word2Vec** uses the embedding layer to find vector representations of words that contain semantic meaning.

# %% [markdown]
# ## Word2Vec
#
# The word2vec algorithm finds much more efficient representations by finding vectors that represent the words. These vectors also contain semantic information about the words. Words that show up in similar contexts, such as "black", "white", and "red" will have vectors near each other. There are two architectures for implementing word2vec, CBOW (Continuous Bag-Of-Words) and Skip-gram.
#
# <img src="assets/word2vec_architectures.png" width="500">
#
# In this implementation, we'll be using the skip-gram architecture because it performs better than CBOW. Here, we pass in a word and try to predict the words surrounding it in the text. In this way, we can train the network to learn representations for words that show up in similar contexts.
#
# First up, importing packages.

# %%
import time

import numpy as np
import tensorflow as tf

import utils

# %% [markdown]
# Load the [text8 dataset](http://mattmahoney.net/dc/textdata.html), a file of cleaned up Wikipedia articles from Matt Mahoney. The next cell will download the data set to the `data` folder. Then you can extract it and delete the archive file to save storage space.

# %%
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import zipfile

dataset_folder_path = 'data'
dataset_filename = 'text8.zip'
dataset_name = 'Text8 Dataset'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(dataset_filename):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc=dataset_name) as pbar:
        urlretrieve(
            'http://mattmahoney.net/dc/text8.zip',
            dataset_filename,
            pbar.hook)

if not isdir(dataset_folder_path):
    with zipfile.ZipFile(dataset_filename) as zip_ref:
        zip_ref.extractall(dataset_folder_path)
        
with open('data/text8') as f:
    text = f.read()
# Out:
# Text8 Dataset: 31.4MB [00:51, 608kB/s]

# %% [markdown]
# ## Preprocessing
#
# Here I'm fixing up the text to make training easier. This comes from the `utils` module I wrote. The `preprocess` function coverts any punctuation into tokens, so a period is changed to ` <PERIOD> `. In this data set, there aren't any periods, but it will help in other NLP problems. I'm also removing all words that show up five or fewer times in the dataset. This will greatly reduce issues due to noise in the data and improve the quality of the vector representations. If you want to write your own functions for this stuff, go for it.

# %%
words = utils.preprocess(text)
print(words[:30])
# Out:
# ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'culottes', 'of', 'the', 'french', 'revolution', 'whilst']

# %%
print("Total words: {}".format(len(words)))
print("Unique words: {}".format(len(set(words))))
# Out:
# Total words: 16680599
# Unique words: 63641

# %% [markdown]
# And here I'm creating dictionaries to convert words to integers and backwards, integers to words. The integers are assigned in descending frequency order, so the most frequent word ("the") is given the integer 0 and the next most frequent is 1 and so on. The words are converted to integers and stored in the list `int_words`.

# %%
vocab_to_int, int_to_vocab = utils.create_lookup_tables(words)
int_words = [vocab_to_int[word] for word in words]

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. This is more of a programming challenge, than about deep learning specifically. But, being able to prepare your data for your network is an important skill to have. Check out my solution to see how I did it.
#
# > **Exercise:** Implement subsampling for the words in `int_words`. That is, go through `int_words` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is the probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
## Your code here
# The idea is to compute the probability formula given above. This is the probability of being discarded.
from collections import Counter
import random

threshold = 1e-5
word_counts = Counter(int_words)
total_count = len(int_words)
#we create two dictionaries. One with the frequencies tied to each word. The other one with the probability to drop the word
freqs = {word: count/total_count for word, count in word_counts.items()}
p_drop = {word: 1 - np.sqrt(threshold/freqs[word]) for word in word_counts}
train_words = [word for word in int_words if random.random() < (1-p_drop[word])] # The final subsampled word list

# %% [markdown]
# ## Making batches

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you choose a random number of words from the window.

# %%
def get_target(words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    # Your code here
    R = np.random.randint(0,window_size+1)
    start_idx = idx - R if (idx - R) > 0 else 0
    end_idx = idx + R if (idx + R) < len(words) else len(words) - 1
    target_words = set(words[start_idx:idx] + words[idx +1:end_idx+1])    
    
    return list(target_words)

# %% [markdown]
# Here's a function that returns batches for our network. The idea is that it grabs `batch_size` words from a words list. Then for each of those words, it gets the target words in the window. I haven't found a way to pass in a random number of target words and get it to work with the architecture, so I make one row per input-target pair. This is a generator function by the way, helps save memory.

# %%
def get_batches(words, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(words)//batch_size
    
    # only full batches
    words = words[:n_batches*batch_size]
    
    for idx in range(0, len(words), batch_size):
        x, y = [], []
        batch = words[idx:idx+batch_size]
        for ii in range(len(batch)):
            batch_x = batch[ii]
            batch_y = get_target(batch, ii, window_size)
            y.extend(batch_y)
            x.extend([batch_x]*len(batch_y))
        yield x, y

# %% [markdown]
# ## Building the graph
#
# From [Chris McCormick's blog](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/), we can see the general structure of our network.
# ![embedding_network](./assets/skip_gram_net_arch.png)
#
# The input words are passed in as integers. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network. We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, shape=None, name='inputs')
    labels = tf.placeholder(tf.int32, shape=[None,None], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
#
# > **Exercise:** Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this lookup for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, I suggest you initialize it with a uniform random numbers between -1 and 1 using [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(int_to_vocab)
n_embedding = 300 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1)) # create embedding weight matrix here
    embed = tf.nn.embedding_lookup(embedding, inputs) # use tf.nn.embedding_lookup to get the hidden layer output

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# > **Exercise:** Below, create weights and biases for the softmax layer. Then, use [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss) to calculate the loss. Be sure to read the documentation to figure out how it works.

# %%
# Number of negative labels to sample
n_sampled = 100
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))# create softmax weight matrix here
    softmax_b = tf.Variable(tf.zeros(n_vocab))# create softmax biases here
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss (softmax_w, softmax_b, labels, embed, n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# This code is from Thushan Ganegedara's implementation. Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keep_dims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))
# Out:
# WARNING:tensorflow:From <ipython-input-14-0edb403d10d5>:13: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints

# %% [markdown]
# ## Training
#
# Below is the code to train the network. Every 100 batches it reports the training loss. Every 1000 batches, it'll print out the validation words.

# %%
epochs = 20
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(train_words, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                ## From Thushan Ganegedara's implementation
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = int_to_vocab[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = int_to_vocab[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    save_path = saver.save(sess, "checkpoints/text8.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/20 Iteration: 100 Avg. Training loss: 5.8033 0.2771 sec/batch
# Epoch 1/20 Iteration: 200 Avg. Training loss: 5.7587 0.2727 sec/batch
# Epoch 1/20 Iteration: 300 Avg. Training loss: 5.6334 0.2738 sec/batch
# Epoch 1/20 Iteration: 400 Avg. Training loss: 5.7131 0.2769 sec/batch
# Epoch 1/20 Iteration: 500 Avg. Training loss: 5.6523 0.2859 sec/batch
# Epoch 1/20 Iteration: 600 Avg. Training loss: 5.6532 0.2867 sec/batch
# Epoch 1/20 Iteration: 700 Avg. Training loss: 5.6525 0.2848 sec/batch
# Epoch 1/20 Iteration: 800 Avg. Training loss: 5.6385 0.2812 sec/batch
# Epoch 1/20 Iteration: 900 Avg. Training loss: 5.5931 0.2792 sec/batch
# Epoch 1/20 Iteration: 1000 Avg. Training loss: 5.5108 0.2802 sec/batch
# Nearest to the: unimpressive, executes, smaller, protects, saud, a, admit, non,
# Nearest to called: coldness, selby, haig, fullwidth, whereupon, lps, yoo, crystals,
# Nearest to time: wishart, surfboard, uncomputable, lasker, iodides, functioned, pedro, lafayette,
# Nearest to eight: hangul, suk, scheme, aiming, sigur, tenji, spearhead, livia,
# Nearest to see: journeyed, awardees, discordian, counterintelligence, compensating, debts, whereabouts, straightforwardly,
# Nearest to with: clarifies, tes, sinc, massachusetts, infamy, publicize, entreaties, evade,
# Nearest to one: anastasia, martyred, nrms, cork, precinct, five, neurotic, quartz,
# Nearest to for: wellman, embrace, constellation, tensions, clinician, abolishing, rectus, bellamy,
# Nearest to operating: ogpu, heuristic, exemplars, foray, surge, nontrivial, triplet, dahlhaus,
# Nearest to magazine: booming, chabad, mdl, snowmen, astatine, ante, benefices, psychotria,
# Nearest to something: holberg, hypnotism, gholas, absolution, tyranny, krestinsky, condensate, absence,
# Nearest to accepted: guilder, downey, romanum, coprophagia, savigny, bechet, servants, castel,
# Nearest to egypt: gadgets, considerations, doubled, akii, parodies, fronted, thumbs, enlightenment,
# Nearest to prince: audiobook, disorder, realizing, bursa, criticize, harmoniously, morpork, bricks,
# Nearest to quite: mpt, fisc, guaran, wyoming, lebesgue, perpetuate, wakayama, aerials,
# Nearest to police: eca, orfeo, mcc, quer, negotiating, exporting, manseriche, sec,
# Epoch 1/20 Iteration: 1100 Avg. Training loss: 5.5918 0.2818 sec/batch
# Epoch 1/20 Iteration: 1200 Avg. Training loss: 5.4764 0.2847 sec/batch
# Epoch 1/20 Iteration: 1300 Avg. Training loss: 5.4081 0.2825 sec/batch
# Epoch 1/20 Iteration: 1400 Avg. Training loss: 5.3617 0.2798 sec/batch
# Epoch 1/20 Iteration: 1500 Avg. Training loss: 5.2645 0.2818 sec/batch
# Epoch 1/20 Iteration: 1600 Avg. Training loss: 5.2309 0.2987 sec/batch
# Epoch 1/20 Iteration: 1700 Avg. Training loss: 5.1858 0.2869 sec/batch
# Epoch 1/20 Iteration: 1800 Avg. Training loss: 5.1356 0.2845 sec/batch
# Epoch 1/20 Iteration: 1900 Avg. Training loss: 5.0871 0.2823 sec/batch
# Epoch 1/20 Iteration: 2000 Avg. Training loss: 5.0709 0.2773 sec/batch
# Nearest to the: non, admit, smaller, unimpressive, another, executes, internal, mode,
# Nearest to called: selby, crystals, whereupon, haig, always, villainous, conference, place,
# Nearest to time: wishart, functioned, lasker, surfboard, encourage, iodides, jacques, pedro,
# Nearest to eight: scheme, aiming, exception, suk, comedy, hangul, wang, chalcedon,
# Nearest to see: journeyed, awardees, discordian, counterintelligence, compensating, debts, yard, straightforwardly,
# Nearest to with: massachusetts, reveal, replacement, publicize, anticlockwise, sinc, may, honours,
# Nearest to one: anastasia, five, martyred, hawkins, singer, rosenzweig, nrms, ngc,
# Nearest to for: embrace, constellation, tensions, wellman, weapon, popular, difficulty, clinician,
# Nearest to operating: ogpu, heuristic, surge, foray, nontrivial, earning, old, exemplars,
# Nearest to magazine: chabad, booming, ante, snowmen, psychotria, dogs, learned, ronnie,
# Nearest to something: holberg, tyranny, absolution, absence, hypnotism, accountability, gholas, affricates,
# Nearest to accepted: guilder, downey, romanum, bechet, castel, harmonized, lean, servants,
# Nearest to egypt: considerations, gadgets, blink, doubled, company, parodies, thumbs, favorably,
# Nearest to prince: audiobook, disorder, realizing, morpork, chuck, criticize, cockney, harmoniously,
# Nearest to quite: approximately, mpt, governmental, wyoming, cities, smith, previously, kindness,
# Nearest to police: eca, orfeo, wish, side, exporting, secretary, managers, fiennes,
# Epoch 1/20 Iteration: 2100 Avg. Training loss: 5.0223 0.2805 sec/batch
# Epoch 1/20 Iteration: 2200 Avg. Training loss: 4.9858 0.2796 sec/batch
# Epoch 1/20 Iteration: 2300 Avg. Training loss: 4.9514 0.2805 sec/batch
# Epoch 1/20 Iteration: 2400 Avg. Training loss: 4.9483 0.2793 sec/batch
# Epoch 1/20 Iteration: 2500 Avg. Training loss: 4.8752 0.2826 sec/batch
# Epoch 1/20 Iteration: 2600 Avg. Training loss: 4.8987 0.2853 sec/batch
# Epoch 1/20 Iteration: 2700 Avg. Training loss: 4.8674 0.2897 sec/batch
# Epoch 1/20 Iteration: 2800 Avg. Training loss: 4.8809 0.2871 sec/batch
# Epoch 1/20 Iteration: 2900 Avg. Training loss: 4.8498 0.2836 sec/batch
# Epoch 1/20 Iteration: 3000 Avg. Training loss: 4.8471 0.2804 sec/batch
# Nearest to the: admit, non, unimpressive, smaller, saud, executes, another, roman,
# Nearest to called: whereupon, selby, villainous, haig, yoo, coldness, always, crystals,
# Nearest to time: functioned, surfboard, wishart, lasker, jacques, encourage, lafayette, pedro,
# Nearest to eight: wang, aiming, comedy, tenji, livia, gleichschaltung, sigur, scheme,
# Nearest to see: journeyed, awardees, discordian, compensating, counterintelligence, debts, whereabouts, yard,
# Nearest to with: massachusetts, reveal, evade, rudolf, anticlockwise, infamy, sinc, routinely,
# Nearest to one: hawkins, five, anastasia, singer, martyred, rosenzweig, johansson, valentine,
# Nearest to for: wellman, embrace, constellation, sediment, tensions, respecting, difficulty, abolishing,
# Nearest to operating: ogpu, heuristic, foray, nontrivial, earning, pluralistic, exemplars, surge,
# Nearest to magazine: chabad, booming, ante, ronnie, snowmen, dogs, racist, psychotria,
# Nearest to something: holberg, tyranny, absolution, accountability, absence, hypnotism, gholas, colour,
# Nearest to accepted: downey, guilder, lean, servants, castel, harmonized, romanum, bechet,
# Nearest to egypt: considerations, gadgets, company, doubled, blink, parodies, enlightenment, thumbs,
# Nearest to prince: audiobook, disorder, criticize, realizing, morpork, harmoniously, cockney, burke,
# Nearest to quite: mpt, wyoming, cities, governmental, fisc, approximately, regained, guaran,
# Nearest to police: negotiating, eca, secretary, managers, philippine, orfeo, enduring, exporting,
# Epoch 1/20 Iteration: 3100 Avg. Training loss: 4.8301 0.2913 sec/batch
# Epoch 1/20 Iteration: 3200 Avg. Training loss: 4.8183 0.2799 sec/batch
# Epoch 1/20 Iteration: 3300 Avg. Training loss: 4.7858 0.2821 sec/batch
# Epoch 1/20 Iteration: 3400 Avg. Training loss: 4.7886 0.2792 sec/batch
# Epoch 1/20 Iteration: 3500 Avg. Training loss: 4.7831 0.2818 sec/batch
# Epoch 1/20 Iteration: 3600 Avg. Training loss: 4.7384 0.2808 sec/batch
# Epoch 1/20 Iteration: 3700 Avg. Training loss: 4.7679 0.2819 sec/batch
# Epoch 1/20 Iteration: 3800 Avg. Training loss: 4.7631 0.2855 sec/batch
# Epoch 1/20 Iteration: 3900 Avg. Training loss: 4.7368 0.2812 sec/batch
# Epoch 1/20 Iteration: 4000 Avg. Training loss: 4.7272 0.2858 sec/batch
# Nearest to the: admit, non, saud, unimpressive, lobbies, roman, bosses, another,
# Nearest to called: whereupon, selby, villainous, coldness, always, haig, yoo, lps,
# Nearest to time: functioned, maoists, wishart, gertrude, lasker, chatham, surfboard, diocletian,
# Nearest to eight: livia, wang, composer, absolved, aden, suk, comedy, named,
# Nearest to see: journeyed, discordian, awardees, compensating, whereabouts, straightforwardly, fptp, yard,
# Nearest to with: massachusetts, reveal, anticlockwise, evade, rudolf, haddock, sinc, infamy,
# Nearest to one: five, singer, hawkins, anastasia, johansson, american, martyred, valentine,
# Nearest to for: wellman, hooke, embrace, respecting, sediment, bund, abolishing, cl,
# Nearest to operating: ogpu, heuristic, pluralistic, nontrivial, foray, exemplars, earning, surge,
# Nearest to magazine: chabad, booming, ante, snowmen, iranians, mdl, racist, ronnie,
# Nearest to something: holberg, tyranny, hypnotism, absolution, gholas, accountability, affricates, savonarola,
# Nearest to accepted: downey, guilder, lean, servants, romanum, bechet, harmonized, castel,
# Nearest to egypt: considerations, company, parodies, blink, gadgets, akii, doubled, bantam,
# Nearest to prince: audiobook, disorder, realizing, criticize, cockney, harmoniously, burke, porte,
# Nearest to quite: mpt, wyoming, cities, fisc, approximately, kindness, lebesgue, guaran,
# Nearest to police: negotiating, eca, orfeo, exporting, quer, wish, philippine, colley,
# Epoch 1/20 Iteration: 4100 Avg. Training loss: 4.7129 0.2879 sec/batch
# Epoch 1/20 Iteration: 4200 Avg. Training loss: 4.7083 0.2835 sec/batch
# Epoch 1/20 Iteration: 4300 Avg. Training loss: 4.6506 0.2842 sec/batch
# Epoch 1/20 Iteration: 4400 Avg. Training loss: 4.6718 0.2822 sec/batch
# Epoch 1/20 Iteration: 4500 Avg. Training loss: 4.6990 0.2856 sec/batch
# Epoch 1/20 Iteration: 4600 Avg. Training loss: 4.6831 0.2895 sec/batch
# Epoch 2/20 Iteration: 4700 Avg. Training loss: 4.6301 0.1997 sec/batch
# Epoch 2/20 Iteration: 4800 Avg. Training loss: 4.5505 0.2844 sec/batch
# Epoch 2/20 Iteration: 4900 Avg. Training loss: 4.5210 0.2907 sec/batch
# Epoch 2/20 Iteration: 5000 Avg. Training loss: 4.5202 0.2773 sec/batch
# Nearest to the: admit, unimpressive, saud, non, cooks, roman, lobbies, bubba,
# Nearest to called: whereupon, coldness, selby, protea, villainous, fullwidth, gwat, interrupt,
# Nearest to time: maoists, snoop, diocletian, gertrude, chatham, uncomputable, functioned, wishart,
# Nearest to eight: composer, wang, jean, livia, two, absolved, anne, william,
# Nearest to see: journeyed, discordian, awardees, compensating, fptp, whereabouts, straightforwardly, yard,
# Nearest to with: reveal, massachusetts, evade, sinc, anticlockwise, clarifies, imaginable, may,
# Nearest to one: five, singer, hawkins, anastasia, american, johansson, taylor, martyred,
# Nearest to for: wellman, abolishing, sediment, embrace, hooke, rectus, bloodline, bund,
# Nearest to operating: heuristic, ogpu, pluralistic, exemplars, flexibility, nontrivial, digital, graphics,
# Nearest to magazine: chabad, booming, ante, snowmen, racist, iranians, mdl, benefices,
# Nearest to something: holberg, tyranny, hypnotism, absolution, accountability, gholas, affricates, savonarola,
# Nearest to accepted: guilder, servants, downey, lean, romanum, immunosuppressive, judo, savigny,
# Nearest to egypt: akii, company, considerations, parodies, prophesying, northumbria, taoists, blink,
# Nearest to prince: audiobook, disorder, augustus, realizing, cockney, bursa, burke, paisley,
# Nearest to quite: mpt, lebesgue, fisc, kindness, guaran, wyoming, approximately, proboscis,
# Nearest to police: negotiating, eca, orfeo, philippine, wish, colley, exporting, secretary,
# Epoch 2/20 Iteration: 5100 Avg. Training loss: 4.5023 0.2792 sec/batch
# Epoch 2/20 Iteration: 5200 Avg. Training loss: 4.4857 0.2780 sec/batch
# Epoch 2/20 Iteration: 5300 Avg. Training loss: 4.4380 0.2798 sec/batch
# Epoch 2/20 Iteration: 5400 Avg. Training loss: 4.5088 0.2792 sec/batch
# Epoch 2/20 Iteration: 5500 Avg. Training loss: 4.4777 0.2811 sec/batch
# Epoch 2/20 Iteration: 5600 Avg. Training loss: 4.4912 0.2845 sec/batch
# Epoch 2/20 Iteration: 5700 Avg. Training loss: 4.4792 0.2784 sec/batch
# Epoch 2/20 Iteration: 5800 Avg. Training loss: 4.3980 0.2807 sec/batch
# Epoch 2/20 Iteration: 5900 Avg. Training loss: 4.4447 0.2818 sec/batch
# Epoch 2/20 Iteration: 6000 Avg. Training loss: 4.4197 0.2820 sec/batch
# Nearest to the: cooks, non, smaller, admit, clear, unimpressive, a, bosses,
# Nearest to called: whereupon, coldness, protea, interrupt, villainous, syntax, nizkor, always,
# Nearest to time: diocletian, rampaging, maoists, snoop, uncomputable, chatham, gertrude, gib,
# Nearest to eight: livia, revoke, hangul, absolved, wang, aden, spearhead, eredivisie,
# Nearest to see: journeyed, discordian, awardees, compensating, straightforwardly, fptp, mcbeal, whereabouts,
# Nearest to with: massachusetts, reveal, imaginable, sinc, evade, anticlockwise, delimiting, clarifies,
# Nearest to one: five, hawkins, anastasia, singer, johansson, nrms, valentine, ngc,
# Nearest to for: wellman, abolishing, embrace, rectus, branding, hooke, respecting, clinician,
# Nearest to operating: heuristic, graphics, ogpu, digital, computers, pluralistic, flexibility, exemplars,
# Nearest to magazine: chabad, booming, ante, iranians, snowmen, racist, benefices, dwindled,
# Nearest to something: holberg, tyranny, hypnotism, absolution, accountability, colour, gholas, affricates,
# Nearest to accepted: guilder, servants, romanum, downey, judo, lean, immunosuppressive, bickering,
# Nearest to egypt: akii, parodies, prophesying, plc, blink, northumbria, cathar, considerations,
# Nearest to prince: audiobook, augustus, realizing, bursa, cockney, burke, porte, harmoniously,
# Nearest to quite: mpt, lebesgue, kindness, fisc, guaran, approximately, euhemerus, immoral,
# Nearest to police: negotiating, eca, orfeo, wish, philippine, colley, exporting, whiston,
# Epoch 2/20 Iteration: 6100 Avg. Training loss: 4.4261 0.2887 sec/batch
# Epoch 2/20 Iteration: 6200 Avg. Training loss: 4.4355 0.2855 sec/batch
# Epoch 2/20 Iteration: 6300 Avg. Training loss: 4.4371 0.2812 sec/batch
# Epoch 2/20 Iteration: 6400 Avg. Training loss: 4.3715 0.2849 sec/batch
# Epoch 2/20 Iteration: 6500 Avg. Training loss: 4.4323 0.2828 sec/batch
# Epoch 2/20 Iteration: 6600 Avg. Training loss: 4.4414 0.2804 sec/batch
# Epoch 2/20 Iteration: 6700 Avg. Training loss: 4.3660 0.2838 sec/batch
# Epoch 2/20 Iteration: 6800 Avg. Training loss: 4.3696 0.2811 sec/batch
# Epoch 2/20 Iteration: 6900 Avg. Training loss: 4.4134 0.2832 sec/batch
# Epoch 2/20 Iteration: 7000 Avg. Training loss: 4.3791 0.2833 sec/batch
# Nearest to the: a, cooks, bubba, smaller, lobbies, clear, unimpressive, is,
# Nearest to called: whereupon, protea, coldness, always, interrupt, lps, villainous, nizkor,
# Nearest to time: diocletian, snoop, rampaging, maoists, experimentation, uncomputable, gertrude, serialised,
# Nearest to eight: eakins, spearhead, aden, wang, ppp, revoke, quintessentially, hangul,
# Nearest to see: journeyed, discordian, awardees, compensating, mcbeal, straightforwardly, fptp, trigeminal,
# Nearest to with: massachusetts, sinc, reveal, imaginable, anticlockwise, delimiting, evade, routinely,
# Nearest to one: five, johansson, hawkins, anastasia, valentine, ngc, singer, zero,
# Nearest to for: wellman, abolishing, rectus, hooke, clinician, respecting, branding, bellamy,
# Nearest to operating: heuristic, ogpu, computers, digital, graphics, pluralistic, flexibility, implementation,
# Nearest to magazine: chabad, booming, ante, dwindled, benefices, racist, iranians, botanic,
# Nearest to something: holberg, tyranny, absolution, affricates, colour, hypnotism, accountability, gholas,
# Nearest to accepted: guilder, servants, romanum, judo, immunosuppressive, lean, downey, savigny,
# Nearest to egypt: akii, parodies, prophesying, cathar, northumbria, giancana, plc, blink,
# Nearest to prince: audiobook, augustus, realizing, bursa, harmoniously, burke, morpork, porte,
# Nearest to quite: mpt, kindness, lebesgue, fisc, mixes, immoral, euhemerus, proboscis,
# Nearest to police: negotiating, orfeo, eca, whiston, lofton, colley, wish, quer,
# Epoch 2/20 Iteration: 7100 Avg. Training loss: 4.3831 0.2853 sec/batch
# Epoch 2/20 Iteration: 7200 Avg. Training loss: 4.3986 0.2838 sec/batch
# Epoch 2/20 Iteration: 7300 Avg. Training loss: 4.3323 0.2876 sec/batch
# Epoch 2/20 Iteration: 7400 Avg. Training loss: 4.3437 0.2806 sec/batch
# Epoch 2/20 Iteration: 7500 Avg. Training loss: 4.3990 0.2771 sec/batch
# Epoch 2/20 Iteration: 7600 Avg. Training loss: 4.3470 0.2894 sec/batch
# Epoch 2/20 Iteration: 7700 Avg. Training loss: 4.3693 0.2980 sec/batch
# Epoch 2/20 Iteration: 7800 Avg. Training loss: 4.3580 0.2872 sec/batch
# Epoch 2/20 Iteration: 7900 Avg. Training loss: 4.3314 0.2904 sec/batch
# Epoch 2/20 Iteration: 8000 Avg. Training loss: 4.3457 0.2754 sec/batch
# Nearest to the: a, lobbies, non, is, clear, smaller, roman, cooks,
# Nearest to called: whereupon, protea, the, nizkor, always, yoo, utf, interrupt,
# Nearest to time: diocletian, snoop, maoists, gertrude, uncomputable, chatham, functioned, rampaging,
# Nearest to eight: eakins, ppp, revoke, five, djiboutian, krause, telemetry, hangul,
# Nearest to see: journeyed, discordian, awardees, mcbeal, fptp, straightforwardly, compensating, illuminating,
# Nearest to with: massachusetts, reveal, anticlockwise, sinc, clarifies, handicrafts, evade, precognition,
# Nearest to one: five, johansson, ngc, anastasia, mortality, zero, nrms, hawkins,
# Nearest to for: wellman, abolishing, clinician, branding, tinkering, hooke, bellamy, rectus,
# Nearest to operating: ogpu, heuristic, computers, graphics, digital, processor, flexibility, implementation,
# Nearest to magazine: chabad, booming, ante, botanic, racist, bac, iranians, toad,
# Nearest to something: holberg, absolution, tyranny, affricates, accountability, gholas, hypnotism, stinger,
# Nearest to accepted: guilder, servants, judo, downey, lean, unity, romanum, germans,
# Nearest to egypt: akii, conquests, cathar, northumbria, prophesying, giancana, parodies, taoists,
# Nearest to prince: audiobook, augustus, realizing, porte, disorder, morpork, burke, bursa,
# Nearest to quite: mpt, kindness, fisc, perpetuate, lebesgue, wyoming, antic, mixes,
# Nearest to police: negotiating, emergency, orfeo, eca, whiston, quer, lofton, philippine,
# Epoch 2/20 Iteration: 8100 Avg. Training loss: 4.3366 0.2755 sec/batch
# Epoch 2/20 Iteration: 8200 Avg. Training loss: 4.3046 0.2782 sec/batch
# Epoch 2/20 Iteration: 8300 Avg. Training loss: 4.4076 0.2977 sec/batch
# Epoch 2/20 Iteration: 8400 Avg. Training loss: 4.3877 0.2846 sec/batch
# Epoch 2/20 Iteration: 8500 Avg. Training loss: 4.3675 0.2879 sec/batch
# Epoch 2/20 Iteration: 8600 Avg. Training loss: 4.3124 0.2890 sec/batch
# Epoch 2/20 Iteration: 8700 Avg. Training loss: 4.2902 0.2885 sec/batch
# Epoch 2/20 Iteration: 8800 Avg. Training loss: 4.3721 0.2891 sec/batch
# Epoch 2/20 Iteration: 8900 Avg. Training loss: 4.2475 0.2882 sec/batch
# Epoch 2/20 Iteration: 9000 Avg. Training loss: 4.3027 0.2858 sec/batch
# Nearest to the: a, kale, archipel, smaller, is, chojnice, subhas, squirrels,
# Nearest to called: protea, whereupon, the, yoo, always, nizkor, utf, coldness,
# Nearest to time: diocletian, snoop, rampaging, paisiello, headlining, maoists, chatham, gertrude,
# Nearest to eight: five, two, ppp, eakins, krause, spearhead, three, andechs,
# Nearest to see: journeyed, discordian, awardees, mcbeal, fptp, illuminating, compensating, countries,
# Nearest to with: massachusetts, delimiting, clarifies, anticlockwise, sinc, reveal, evade, entreaties,
# Nearest to one: five, johansson, two, anastasia, zero, singer, mortality, colonist,
# Nearest to for: wellman, abolishing, clinician, zf, tinkering, hooke, rectus, constellation,
# Nearest to operating: ogpu, heuristic, processor, implementation, graphics, computers, digital, distributions,
# Nearest to magazine: chabad, booming, ante, racist, botanic, arbitron, toad, benefices,
# Nearest to something: holberg, absolution, tyranny, affricates, gholas, accountability, scorer, hypnotism,
# Nearest to accepted: guilder, romanum, downey, lean, harmonized, servants, savigny, bechet,
# Nearest to egypt: akii, conquests, cathar, phoenicians, northumbria, giancana, prophesying, taoists,
# Nearest to prince: audiobook, augustus, bursa, porte, realizing, morpork, disorder, burke,
# Nearest to quite: mpt, kindness, fisc, mixes, lebesgue, perpetuate, tlc, ahijah,
# Nearest to police: negotiating, whiston, emergency, orfeo, lofton, eca, quer, wish,
# Epoch 2/20 Iteration: 9100 Avg. Training loss: 4.2985 0.2848 sec/batch
# Epoch 2/20 Iteration: 9200 Avg. Training loss: 4.3079 0.2822 sec/batch
# Epoch 3/20 Iteration: 9300 Avg. Training loss: 4.3410 0.1175 sec/batch
# Epoch 3/20 Iteration: 9400 Avg. Training loss: 4.2331 0.2822 sec/batch
# Epoch 3/20 Iteration: 9500 Avg. Training loss: 4.1944 0.2821 sec/batch
# Epoch 3/20 Iteration: 9600 Avg. Training loss: 4.1946 0.2812 sec/batch
# Epoch 3/20 Iteration: 9700 Avg. Training loss: 4.2151 0.2836 sec/batch
# Epoch 3/20 Iteration: 9800 Avg. Training loss: 4.2027 0.2828 sec/batch
# Epoch 3/20 Iteration: 9900 Avg. Training loss: 4.1999 0.2698 sec/batch
# Epoch 3/20 Iteration: 10000 Avg. Training loss: 4.1596 0.2712 sec/batch
# Nearest to the: a, called, is, smaller, archipel, kale, canute, subhas,
# Nearest to called: the, protea, yoo, whereupon, parametric, utf, always, gwat,
# Nearest to time: diocletian, headlining, rampaging, paisiello, maoists, gertrude, snoop, uncomputable,
# Nearest to eight: five, two, eakins, ppp, spearhead, three, six, revoke,
# Nearest to see: journeyed, discordian, mcbeal, awardees, hervarar, fptp, compensating, illuminating,
# Nearest to with: delimiting, massachusetts, sinc, evade, anticlockwise, handicrafts, device, erred,
# Nearest to one: five, johansson, zero, two, mortality, anastasia, ngc, colonist,
# Nearest to for: wellman, clinician, tinkering, bitmapped, abolishing, tensions, geophysical, branding,
# Nearest to operating: heuristic, ogpu, processor, graphics, multitasking, pluralistic, implementation, computers,
# Nearest to magazine: chabad, booming, dwindled, botanic, ante, toad, bac, benefices,
# Nearest to something: holberg, tyranny, affricates, absolution, gholas, scorer, hypnotism, accountability,
# Nearest to accepted: guilder, romanum, savigny, lean, harmonized, downey, immunosuppressive, unity,
# Nearest to egypt: conquests, akii, northumbria, cathar, prophesying, phoenicians, giancana, axe,
# Nearest to prince: audiobook, augustus, bursa, porte, realizing, courtenay, morpork, paisley,
# Nearest to quite: mpt, kindness, fisc, mixes, perpetuate, antic, proboscis, lebesgue,
# Nearest to police: negotiating, whiston, orfeo, emergency, lofton, quer, eca, wish,
# Epoch 3/20 Iteration: 10100 Avg. Training loss: 4.2093 0.2735 sec/batch
# Epoch 3/20 Iteration: 10200 Avg. Training loss: 4.2165 0.2744 sec/batch
# Epoch 3/20 Iteration: 10300 Avg. Training loss: 4.1987 0.2737 sec/batch
# Epoch 3/20 Iteration: 10400 Avg. Training loss: 4.1076 0.2733 sec/batch
# Epoch 3/20 Iteration: 10500 Avg. Training loss: 4.1216 0.2730 sec/batch
# Epoch 3/20 Iteration: 10600 Avg. Training loss: 4.1337 0.2874 sec/batch
# Epoch 3/20 Iteration: 10700 Avg. Training loss: 4.1475 0.2796 sec/batch
# Epoch 3/20 Iteration: 10800 Avg. Training loss: 4.1533 0.2771 sec/batch
# Epoch 3/20 Iteration: 10900 Avg. Training loss: 4.1646 0.2777 sec/batch
# Epoch 3/20 Iteration: 11000 Avg. Training loss: 4.1564 0.2963 sec/batch
# Nearest to the: a, is, called, kale, compartment, habr, archipel, smaller,
# Nearest to called: the, protea, parametric, utf, always, crystals, yoo, whereupon,
# Nearest to time: diocletian, rampaging, headlining, paisiello, uncomputable, gertrude, snoop, gib,
# Nearest to eight: five, ppp, eakins, djiboutian, three, two, six, spearhead,
# Nearest to see: journeyed, discordian, mcbeal, awardees, compensating, religion, illuminating, fptp,
# Nearest to with: massachusetts, delimiting, sinc, device, imaginable, reveal, anticlockwise, clarifies,
# Nearest to one: five, zero, johansson, two, ngc, mortality, anastasia, four,
# Nearest to for: wellman, bitmapped, clinician, tinkering, zf, hooke, branding, bloodline,
# Nearest to operating: heuristic, processor, ogpu, implementation, scanners, flexibility, cvs, multitasking,
# Nearest to magazine: chabad, booming, botanic, benefices, bac, dwindled, toad, ante,
# Nearest to something: holberg, affricates, tyranny, absolution, scorer, gholas, accountability, hurry,
# Nearest to accepted: romanum, lean, harmonized, guilder, savigny, immunosuppressive, judo, servants,
# Nearest to egypt: conquests, cathar, northumbria, phoenicians, akii, giancana, prophesying, parodies,
# Nearest to prince: audiobook, augustus, bursa, realizing, courtenay, porte, morpork, franconian,
# Nearest to quite: mpt, fisc, mixes, proboscis, kindness, ruin, ahijah, immoral,
# Nearest to police: whiston, emergency, negotiating, eca, orfeo, quer, railtrack, lofton,
# Epoch 3/20 Iteration: 11100 Avg. Training loss: 4.1628 0.3031 sec/batch
# Epoch 3/20 Iteration: 11200 Avg. Training loss: 4.2295 0.2983 sec/batch
# Epoch 3/20 Iteration: 11300 Avg. Training loss: 4.1740 0.2986 sec/batch
# Epoch 3/20 Iteration: 11400 Avg. Training loss: 4.1520 0.2941 sec/batch
# Epoch 3/20 Iteration: 11500 Avg. Training loss: 4.1701 0.2843 sec/batch
# Epoch 3/20 Iteration: 11600 Avg. Training loss: 4.1712 0.2790 sec/batch
# Epoch 3/20 Iteration: 11700 Avg. Training loss: 4.1836 0.2940 sec/batch
# Epoch 3/20 Iteration: 11800 Avg. Training loss: 4.1533 0.2792 sec/batch
# Epoch 3/20 Iteration: 11900 Avg. Training loss: 4.1285 0.2779 sec/batch
# Epoch 3/20 Iteration: 12000 Avg. Training loss: 4.1898 0.2786 sec/batch
# Nearest to the: a, is, called, habr, kale, archipel, in, compartment,
# Nearest to called: the, protea, yoo, parametric, always, phonetically, gwat, whereupon,
# Nearest to time: diocletian, paisiello, rampaging, maoists, uncomputable, gertrude, functioned, headlining,
# Nearest to eight: five, three, two, eakins, six, djiboutian, ppp, krause,
# Nearest to see: discordian, journeyed, mcbeal, awardees, landen, illuminating, fptp, ed,
# Nearest to with: delimiting, sinc, massachusetts, clarifies, device, precognition, cadmus, anticlockwise,
# Nearest to one: five, zero, two, johansson, ngc, mortality, four, three,
# Nearest to for: wellman, top, zf, bitmapped, hooke, tinkering, clinician, kluge,
# Nearest to operating: heuristic, scanners, ogpu, processor, implementation, cvs, distributions, ported,
# Nearest to magazine: chabad, booming, bac, benefices, toad, dwindled, botanic, snowmen,
# Nearest to something: holberg, affricates, tyranny, absolution, gholas, hypnotism, accountability, scorer,
# Nearest to accepted: romanum, harmonized, lean, immunosuppressive, guilder, judo, savigny, unity,
# Nearest to egypt: conquests, giancana, cathar, cephalopods, var, bronze, phoenicians, parodies,
# Nearest to prince: augustus, audiobook, realizing, bursa, morpork, courtenay, porte, franconian,
# Nearest to quite: mpt, fisc, proboscis, mixes, wyoming, kindness, ahijah, antic,
# Nearest to police: emergency, negotiating, whiston, railtrack, eca, quer, orfeo, lofton,
# Epoch 3/20 Iteration: 12100 Avg. Training loss: 4.1697 0.2816 sec/batch
# Epoch 3/20 Iteration: 12200 Avg. Training loss: 4.1916 0.3092 sec/batch
# Epoch 3/20 Iteration: 12300 Avg. Training loss: 4.1375 0.2972 sec/batch
# Epoch 3/20 Iteration: 12400 Avg. Training loss: 4.1642 0.2973 sec/batch
# Epoch 3/20 Iteration: 12500 Avg. Training loss: 4.1248 0.2830 sec/batch
# Epoch 3/20 Iteration: 12600 Avg. Training loss: 4.1322 0.2802 sec/batch
# Epoch 3/20 Iteration: 12700 Avg. Training loss: 4.1508 0.2782 sec/batch
# Epoch 3/20 Iteration: 12800 Avg. Training loss: 4.1261 0.2944 sec/batch
# Epoch 3/20 Iteration: 12900 Avg. Training loss: 4.1602 0.2835 sec/batch
# Epoch 3/20 Iteration: 13000 Avg. Training loss: 4.1860 0.2867 sec/batch
# Nearest to the: a, is, called, in, sanusi, habr, archipel, jeffersonian,
# Nearest to called: the, protea, yoo, always, whereupon, gwat, phonetically, nizkor,
# Nearest to time: diocletian, novellae, wishart, paisiello, gertrude, maoists, functioned, headlining,
# Nearest to eight: five, eakins, three, six, two, nine, krause, andechs,
# Nearest to see: journeyed, discordian, mcbeal, awardees, illuminating, landen, compensating, lachine,
# Nearest to with: massachusetts, entreaties, delimiting, clarifies, hillbillies, hay, erred, device,
# Nearest to one: five, zero, two, johansson, four, three, anastasia, nine,
# Nearest to for: of, zf, tinkering, herdsmen, bitmapped, wellman, hooke, bloodline,
# Nearest to operating: heuristic, scanners, ogpu, processor, zilog, distributions, edwardian, cvs,
# Nearest to magazine: chabad, booming, weekly, snowmen, toad, botanic, benefices, bac,
# Nearest to something: holberg, tyranny, absolution, affricates, gholas, accountability, hypnotism, hurry,
# Nearest to accepted: romanum, harmonized, savigny, lean, guilder, adherence, bechet, unity,
# Nearest to egypt: conquests, giancana, phoenicians, cathar, suez, axe, bronze, var,
# Nearest to prince: audiobook, augustus, realizing, courtenay, morpork, bursa, franconian, porte,
# Nearest to quite: mpt, fisc, proboscis, mixes, ahijah, kindness, perpetuate, aerials,
# Nearest to police: emergency, whiston, negotiating, orfeo, quer, railtrack, hamid, victims,
# Epoch 3/20 Iteration: 13100 Avg. Training loss: 4.2024 0.3041 sec/batch
# Epoch 3/20 Iteration: 13200 Avg. Training loss: 4.1349 0.2882 sec/batch
# Epoch 3/20 Iteration: 13300 Avg. Training loss: 4.1132 0.2840 sec/batch
# Epoch 3/20 Iteration: 13400 Avg. Training loss: 4.1381 0.2874 sec/batch
# Epoch 3/20 Iteration: 13500 Avg. Training loss: 4.0762 0.2946 sec/batch
# Epoch 3/20 Iteration: 13600 Avg. Training loss: 4.1074 0.2778 sec/batch
# Epoch 3/20 Iteration: 13700 Avg. Training loss: 4.1167 0.2929 sec/batch
# Epoch 3/20 Iteration: 13800 Avg. Training loss: 4.1188 0.3046 sec/batch
# Epoch 4/20 Iteration: 13900 Avg. Training loss: 4.1381 0.0367 sec/batch
# Epoch 4/20 Iteration: 14000 Avg. Training loss: 4.1022 0.3128 sec/batch
# Nearest to the: a, is, called, in, kale, equinoxes, compartment, ah,
# Nearest to called: the, protea, yoo, always, phonetically, parametric, beads, gwat,
# Nearest to time: novellae, diocletian, paisiello, appropriations, gertrude, wishart, headlining, vangelis,
# Nearest to eight: five, six, two, three, nine, ppp, eakins, krause,
# Nearest to see: journeyed, discordian, mcbeal, illuminating, awardees, landen, compensating, fptp,
# Nearest to with: massachusetts, delimiting, device, sinc, precognition, clarifies, entreaties, anticlockwise,
# Nearest to one: five, zero, two, johansson, four, ngc, three, nine,
# Nearest to for: herdsmen, bitmapped, constellation, clinician, tinkering, top, wellman, bloodline,
# Nearest to operating: heuristic, scanners, edwardian, distributions, communicator, ogpu, zilog, processor,
# Nearest to magazine: chabad, booming, weekly, snowmen, toad, cine, bac, bags,
# Nearest to something: holberg, tyranny, affricates, absolution, gholas, accountability, hypnotism, hurry,
# Nearest to accepted: romanum, harmonized, savigny, lean, unity, guilder, periodization, adherence,
# Nearest to egypt: conquests, cathar, phoenicians, giancana, berbers, pharaoh, banna, axe,
# Nearest to prince: audiobook, courtenay, bursa, augustus, realizing, morpork, porte, franconian,
# Nearest to quite: mpt, mixes, fisc, proboscis, ahijah, sewer, roach, aerials,
# Nearest to police: emergency, negotiating, whiston, quer, orfeo, armed, hamid, victims,
# Epoch 4/20 Iteration: 14100 Avg. Training loss: 4.0479 0.3075 sec/batch
# Epoch 4/20 Iteration: 14200 Avg. Training loss: 4.0554 0.2794 sec/batch
# Epoch 4/20 Iteration: 14300 Avg. Training loss: 4.0796 0.2654 sec/batch
# Epoch 4/20 Iteration: 14400 Avg. Training loss: 4.0396 0.2654 sec/batch
# Epoch 4/20 Iteration: 14500 Avg. Training loss: 4.0379 0.2660 sec/batch
# Epoch 4/20 Iteration: 14600 Avg. Training loss: 4.0122 0.2652 sec/batch
# Epoch 4/20 Iteration: 14700 Avg. Training loss: 4.0515 0.2659 sec/batch
# Epoch 4/20 Iteration: 14800 Avg. Training loss: 4.0816 0.2711 sec/batch
# Epoch 4/20 Iteration: 14900 Avg. Training loss: 4.0853 0.2711 sec/batch
# Epoch 4/20 Iteration: 15000 Avg. Training loss: 4.0064 0.2703 sec/batch
# Nearest to the: a, is, in, called, habr, equinoxes, archipel, sanusi,
# Nearest to called: the, protea, yoo, parametric, always, beads, interrupt, phonetically,
# Nearest to time: diocletian, novellae, paisiello, vangelis, appropriations, headlining, chatham, wishart,
# Nearest to eight: five, six, three, two, ppp, nine, eakins, djiboutian,
# Nearest to see: discordian, journeyed, mcbeal, illuminating, awardees, compensating, landen, hervarar,
# Nearest to with: device, massachusetts, delimiting, precognition, clarifies, sinc, anticlockwise, it,
# Nearest to one: five, zero, two, johansson, three, ngc, four, nine,
# Nearest to for: bitmapped, of, herdsmen, checkers, tinkering, zf, top, fit,
# Nearest to operating: heuristic, scanners, processor, multitasking, clones, communicator, edwardian, distributions,
# Nearest to magazine: chabad, weekly, booming, toad, snowmen, bac, amazonite, femme,
# Nearest to something: affricates, tyranny, holberg, accountability, gholas, absolution, hurry, rockstar,
# Nearest to accepted: romanum, harmonized, savigny, lean, pusc, judo, guilder, periodization,
# Nearest to egypt: conquests, giancana, cathar, phoenicians, axe, banna, berbers, var,
# Nearest to prince: audiobook, courtenay, bursa, realizing, augustus, franconian, morpork, porte,
# Nearest to quite: mpt, mixes, fisc, proboscis, sewer, antic, aerials, ahijah,
# Nearest to police: emergency, whiston, negotiating, orfeo, victims, quer, railtrack, hamid,
# Epoch 4/20 Iteration: 15100 Avg. Training loss: 3.9908 0.2691 sec/batch
# Epoch 4/20 Iteration: 15200 Avg. Training loss: 3.9913 0.2677 sec/batch
# Epoch 4/20 Iteration: 15300 Avg. Training loss: 3.9920 0.2662 sec/batch
# Epoch 4/20 Iteration: 15400 Avg. Training loss: 4.0120 0.2745 sec/batch
# Epoch 4/20 Iteration: 15500 Avg. Training loss: 4.0179 0.2761 sec/batch
# Epoch 4/20 Iteration: 15600 Avg. Training loss: 4.0414 0.3076 sec/batch
# Epoch 4/20 Iteration: 15700 Avg. Training loss: 4.0456 0.2912 sec/batch
# Epoch 4/20 Iteration: 15800 Avg. Training loss: 4.1021 0.2906 sec/batch
# Epoch 4/20 Iteration: 15900 Avg. Training loss: 4.0367 0.2965 sec/batch
# Epoch 4/20 Iteration: 16000 Avg. Training loss: 4.0111 0.2869 sec/batch
# Nearest to the: is, a, in, called, archipel, equinoxes, habr, compartment,
# Nearest to called: the, protea, yoo, parametric, always, phonetically, diagrams, formed,
# Nearest to time: diocletian, paisiello, novellae, vangelis, gib, bytes, appropriations, rampaging,
# Nearest to eight: five, six, three, nine, two, zero, eakins, ppp,
# Nearest to see: discordian, journeyed, illuminating, mcbeal, compensating, landen, ed, awardees,
# Nearest to with: device, sinc, massachusetts, entreaties, delimiting, precognition, indoors, polygon,
# Nearest to one: five, zero, two, three, johansson, ngc, four, nine,
# Nearest to for: of, bitmapped, zf, herdsmen, checkers, tinkering, hooke, top,
# Nearest to operating: heuristic, scanners, flexibility, xn, distributions, multitasking, cvs, ogpu,
# Nearest to magazine: chabad, weekly, booming, toad, femme, amazonite, bac, cine,
# Nearest to something: affricates, absolution, tyranny, gholas, holberg, fraca, accountability, hurry,
# Nearest to accepted: romanum, pusc, savigny, harmonized, lean, periodization, immunosuppressive, judo,
# Nearest to egypt: suez, conquests, giancana, berbers, var, cathar, pharaoh, considerations,
# Nearest to prince: audiobook, courtenay, bursa, franconian, augustus, realizing, morpork, porte,
# Nearest to quite: mpt, mixes, proboscis, fisc, sewer, aerials, immoral, carnation,
# Nearest to police: whiston, negotiating, emergency, victims, orfeo, quer, railtrack, hamid,
# Epoch 4/20 Iteration: 16100 Avg. Training loss: 4.0336 0.2858 sec/batch
# Epoch 4/20 Iteration: 16200 Avg. Training loss: 4.0756 0.2913 sec/batch
# Epoch 4/20 Iteration: 16300 Avg. Training loss: 4.0273 0.3348 sec/batch
# Epoch 4/20 Iteration: 16400 Avg. Training loss: 4.0408 0.2893 sec/batch
# Epoch 4/20 Iteration: 16500 Avg. Training loss: 4.0748 0.2748 sec/batch
# Epoch 4/20 Iteration: 16600 Avg. Training loss: 4.0233 0.2859 sec/batch
# Epoch 4/20 Iteration: 16700 Avg. Training loss: 4.0352 0.2798 sec/batch
# Epoch 4/20 Iteration: 16800 Avg. Training loss: 4.0574 0.2802 sec/batch
# Epoch 4/20 Iteration: 16900 Avg. Training loss: 4.0787 0.2916 sec/batch
# Epoch 4/20 Iteration: 17000 Avg. Training loss: 4.0295 0.2929 sec/batch
# Nearest to the: a, in, is, of, called, sanusi, habr, archipel,
# Nearest to called: the, protea, yoo, always, gwat, phonetically, names, parametric,
# Nearest to time: diocletian, paisiello, novellae, appropriations, wishart, functioned, gertrude, vangelis,
# Nearest to eight: five, six, three, nine, two, eakins, zero, djiboutian,
# Nearest to see: discordian, journeyed, mcbeal, illuminating, landen, compensating, campbell, external,
# Nearest to with: device, precognition, it, massachusetts, presidents, entreaties, gie, indoors,
# Nearest to one: five, zero, two, three, four, nine, ngc, johansson,
# Nearest to for: of, zf, herdsmen, bitmapped, tinkering, hooke, top, astrologically,
# Nearest to operating: heuristic, cvs, scanners, multitasking, distributions, edwardian, communicator, flexibility,
# Nearest to magazine: chabad, weekly, booming, toad, snowmen, bac, cine, amazonite,
# Nearest to something: affricates, holberg, absolution, accountability, tyranny, gholas, hurry, stinger,
# Nearest to accepted: romanum, lean, harmonized, periodization, pusc, adherence, savigny, immunosuppressive,
# Nearest to egypt: suez, giancana, conquests, berbers, pharaoh, cathar, var, banna,
# Nearest to prince: courtenay, audiobook, franconian, augustus, bursa, morpork, porte, realizing,
# Nearest to quite: mpt, mixes, fisc, proboscis, antic, aerials, carnation, roach,
# Nearest to police: emergency, whiston, negotiating, victims, quer, orfeo, hamid, railtrack,
# Epoch 4/20 Iteration: 17100 Avg. Training loss: 4.0095 0.2975 sec/batch
# Epoch 4/20 Iteration: 17200 Avg. Training loss: 4.0060 0.2874 sec/batch
# Epoch 4/20 Iteration: 17300 Avg. Training loss: 4.0143 0.2816 sec/batch
# Epoch 4/20 Iteration: 17400 Avg. Training loss: 4.0711 0.2878 sec/batch
# Epoch 4/20 Iteration: 17500 Avg. Training loss: 4.0190 0.2773 sec/batch
# Epoch 4/20 Iteration: 17600 Avg. Training loss: 4.0998 0.2752 sec/batch
# Epoch 4/20 Iteration: 17700 Avg. Training loss: 4.1174 0.2832 sec/batch
# Epoch 4/20 Iteration: 17800 Avg. Training loss: 4.0374 0.2771 sec/batch
# Epoch 4/20 Iteration: 17900 Avg. Training loss: 3.9789 0.2780 sec/batch
# Epoch 4/20 Iteration: 18000 Avg. Training loss: 4.0263 0.2793 sec/batch
# Nearest to the: is, a, in, called, sanusi, and, archipel, equinoxes,
# Nearest to called: the, protea, yoo, always, gwat, phonetically, names, parametric,
# Nearest to time: paisiello, diocletian, appropriations, wishart, novellae, vangelis, zhang, paused,
# Nearest to eight: five, six, three, two, nine, eakins, zero, quisling,
# Nearest to see: journeyed, discordian, illuminating, mcbeal, landen, campbell, lachine, awardees,
# Nearest to with: device, delimiting, massachusetts, hillbillies, polygon, indoors, reassurance, sinc,
# Nearest to one: five, zero, two, nine, four, three, ngc, johansson,
# Nearest to for: of, zf, bitmapped, fit, herdsmen, top, hooke, kluge,
# Nearest to operating: heuristic, cvs, distributions, edwardian, communicator, scanners, xn, zilog,
# Nearest to magazine: chabad, weekly, booming, snowmen, bac, toad, bags, quarterly,
# Nearest to something: affricates, absolution, tyranny, accountability, gholas, hurry, holberg, hypnotism,
# Nearest to accepted: romanum, lean, periodization, adherence, savigny, pusc, lessons, unverified,
# Nearest to egypt: giancana, suez, conquests, berbers, pharaoh, banna, cathar, var,
# Nearest to prince: courtenay, audiobook, franconian, bursa, augustus, morpork, porte, patay,
# Nearest to quite: mpt, mixes, fisc, proboscis, aerials, immoral, antic, fingerboard,
# Nearest to police: emergency, victims, whiston, negotiating, quer, hamid, orfeo, railtrack,
# Epoch 4/20 Iteration: 18100 Avg. Training loss: 3.9732 0.2810 sec/batch
# Epoch 4/20 Iteration: 18200 Avg. Training loss: 3.9968 0.2849 sec/batch
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-57065ced11b0> in <module>()
#      18             feed = {inputs: x,
#      19                     labels: np.array(y)[:, None]}
# ---> 20             train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
#      21
#      22             loss += train_loss
#
# ~/anaconda/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     875     try:
#     876       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 877                          run_metadata_ptr)
#     878       if run_metadata:
#     879         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1098     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1099       results = self._do_run(handle, final_targets, final_fetches,
# -> 1100                              feed_dict_tensor, options, run_metadata)
#    1101     else:
#    1102       results = []
#
# ~/anaconda/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1270     if handle is None:
#    1271       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1272                            run_metadata)
#    1273     else:
#    1274       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# ~/anaconda/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1276   def _do_call(self, fn, *args):
#    1277     try:
# -> 1278       return fn(*args)
#    1279     except errors.OpError as e:
#    1280       message = compat.as_text(e.message)
#
# ~/anaconda/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1261       self._extend_graph()
#    1262       return self._call_tf_sessionrun(
# -> 1263           options, feed_dict, fetch_list, target_list, run_metadata)
#    1264
#    1265     def _prun_fn(handle, feed_dict, fetch_list):
#
# ~/anaconda/envs/tensorflow/lib/python3.5/site-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1348     return tf_session.TF_SessionRun_wrapper(
#    1349         self._session, options, feed_dict, fetch_list, target_list,
# -> 1350         run_metadata)
#    1351
#    1352   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# Restore the trained network if you need to:

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/text8.ckpt

# %% [markdown]
# ## Visualizing the word vectors
#
# Below we'll use T-SNE to visualize how our high-dimensional word vectors cluster together. T-SNE is used to project these vectors into two dimensions while preserving local stucture. Check out [this post from Christopher Olah](http://colah.github.io/posts/2014-10-Visualizing-MNIST/) to learn more about T-SNE and other ways to visualize high-dimensional data.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(30, 30))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(int_to_vocab[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)
